# %%
from Utah_LSTM import *
plt.switch_backend("nbagg")
plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 18})
plt.rcParams['savefig.dpi'] = 80
plt.rcParams['figure.figsize']=14,14

# %% [markdown]
# ## Build a dataframe with (fixed width) db files

# %% [markdown]
# ### you will need an event file that looks something like this:
#
# ![Screen%20Shot%202018-02-01%20at%204.17.02%20PM.png](attachment:Screen%20Shot%202018-02-01%20at%204.17.02%20PM.png)
#
# ### and pickfiles for each class...
#
# ![Screen%20Shot%202018-02-01%20at%204.17.25%20PM.png](attachment:Screen%20Shot%202018-02-01%20at%204.17.25%20PM.png)

# %%
data = preproc_data(parse_dbselect(),num_events=5)
# Out:
# sucessfully processed 5 events

# %% [markdown]
# ### data contains spectrograms, event metadata and classification results

# %%
print(data.iloc[0])
# Out:
# chan                                                         EHZ
# datetime                             2012-10-01T10:05:52.580000Z
# depth                                                      15.39
# dist                                                     87111.9
# dsize                                                     single
# evla                                                     44.6752
# evlo                                                     -110.04
# id                                                      60000092
# impulsive                                                     IP
# lbl                                                            0
# mag                                                         0.25
# net                                                           MB
# station                                                     CRMT
# stla                                                     45.4558
# ...

# %%
plt_events(data)
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/World_Shaded_Relief/MapServer/export?bbox=589110.8500480326,1440424.5680996615,631388.7347078056,1581880.9631240857&bboxSR=32142&imageSR=32142&size=1500,5018&dpi=96&format=png32&f=image

# %%
make_stats(data)
# Out:
#    class_prediction                     datetime  depth     evla    evlo  \
# 0                 0  2012-10-01T10:05:52.580000Z  15.39  44.6752 -110.04
#
#    how_sure        id   mag                    stations  type
# 0  0.648825  60000092  0.25  [CRMT, YLA, YMP, YPK, YTP]     0
