# %%
from Utah_LSTM import *
plt.switch_backend("nbagg")
plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 18})
plt.rcParams['savefig.dpi'] = 80
plt.rcParams['figure.figsize']=14,14
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Build a dataframe with (fixed width) db files

# %% [markdown]
# ### you will need an event file that looks something like this:
#
# ![screen4.png](https://github.com/quapity/UUSS_LSTM_classification/raw/master/figures/screen4.png)
#
# ### and pickfiles for each class...
#
# ![screen5.png](https://github.com/quapity/UUSS_LSTM_classification/raw/master/figures/screen5.png)

# %%
data = preproc_data(parse_dbselect(),num_lines=15)
# Out:
# sucessfully processed 15 examples from 3 events

# %% [markdown]
# ### data contains spectrograms, event metadata and classification results

# %%
print(data.iloc[0])
# Out:
# chan                                                         EHZ
# datetime                             2012-10-01T10:05:52.580000Z
# depth                                                      15.39
# dist                                                     87111.9
# dsize                                                     single
# evla                                                     44.6752
# evlo                                                     -110.04
# id                                                      60000092
# impulsive                                                     IP
# lbl                                                            0
# mag                                                         0.25
# net                                                           MB
# station                                                     CRMT
# stla                                                     45.4558
# ...

# %%
plt_events(data)

# %%
make_stats(data)
# Out:
#    class_prediction                     datetime  depth     evla      evlo  \
# 0                 0  2012-10-01T14:25:01.330000Z   5.97  44.4598 -110.9865
# 1                 0  2012-10-01T14:20:34.720000Z  16.18  44.4423 -111.0167
# 2                 0  2012-10-01T14:27:40.570000Z   6.00  44.4455 -111.0510
# 3                 0  2012-10-01T14:24:45.570000Z   6.05  44.4382 -111.0320
# 4                 0  2012-10-01T16:51:45.900000Z  19.54  39.1405 -111.6550
# 5                 0  2012-10-01T10:05:52.580000Z  15.39  44.6752 -110.0400
# 6                 0  2012-10-01T14:59:28.500000Z   5.96  44.4507 -111.0330
#
#    how_sure        id   mag                                          stations  \
# 0  0.947974  60000096  1.11                                   [YMR, YPP, YWB]
# 1  0.828543  60000097  0.93  [FLWY, B207, MCID, YHB, YHH, YHL, YMR, YPM, YWB]
# 2  0.838733  60000101  1.39                       [B207, MCID, YMR, YPM, YPP]
# ...
